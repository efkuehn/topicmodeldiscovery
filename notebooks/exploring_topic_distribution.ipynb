# %% [markdown]
# # Find the Dominant Document For Each Topic
#
# Once we have a topic model that has pretty good distribution and the bags of words have fairly coherent topics, we needed to explore the specific topics in the corpus. To do this, we created a pandas dataframe that works similarly to a spreadsheet, but allows all of the functionality of python on top of it.
#
# The firest two cells import the necessary modules, and load the data.

# %%
import pandas as pd
import json
from gensim import corpora 
from gensim.models.ldamodel import LdaModel 
from gensim.corpora.dictionary import Dictionary

# %%
lda_model = LdaModel.load('./models/PrelimTOpicModel2') 
corpus_dict = Dictionary.load_from_text('./models/corpus_dictionary_2')
with open('./models/corpus.json', 'r') as fp:
    corpus = json.load(fp)
with open('./models/text_list.json', 'r') as fp:
    text_list = json.load(fp)
with open('./models/corpus_list.json', 'r') as fp:
    corpus_list = json.load(fp)

# %% [markdown]
# The following code is the primary function that creates the dataframe. This dataframe has a row for each page in the document. Which topic is dominant for the words on the page, and what the distinctive words are for the given topic. It also includes the pdf and page number for the document we are analyzing.
#
# This allowed us to go back and look at the page for further context, in order to better understand the topics.

# %%
# this creates a pandas DataFrame that orders all of the topics and shows the dominant topic for each document
def format_topics_sent(ldamodel, corpus, texts):
    sent_topics_df = pd.DataFrame()
    for i, row in enumerate(ldamodel[corpus]):
        row = sorted(row[0], key=lambda x: x[1], reverse=True)
        
        for j, (topic_num, prop_topic) in enumerate(row):
            if j == 0:
                wp = ldamodel.show_topic(topic_num)
                topic_keywords = ", ".join([word for word, prop in wp])
                sent_topics_df = sent_topics_df.append(pd.Series([int(topic_num), round(prop_topic,4), topic_keywords]), ignore_index=True)
            else:
                break
    sent_topics_df.columns = ['Dominant_topic', 'Perc_Contrib', 'Topic_Keywords']
    contents = pd.Series(texts)
    sent_topics_df = pd.concat([sent_topics_df, contents], axis=1)
    sent_topics_df.rename(columns={0: "Text"}, inplace=True)
    return sent_topics_df

# %% [markdown]
# ## Exploring the Dominant Topic Models
#
# In order to better understand the specifics of this code, we can explore each particular row, by creating a generator to look at the rows.

# %%
def format_topics_sent_gen(ldamodel, corpus, texts):
    for i, row in enumerate(ldamodel[corpus]):
        yield row

# %%
row_generator = format_topics_sent_gen(lda_model, corpus, corpus_list)

# %%
row = next(row_generator)

# %%
row
# Out:
# ([(0, 0.010000001),
#   (1, 0.010000001),
#   (2, 0.010000001),
#   (3, 0.010000001),
#   (4, 0.010000001),
#   (5, 0.010000001),
#   (6, 0.010000001),
#   (7, 0.010000001),
#   (8, 0.010000001),
#   (9, 0.76),
#   (10, 0.010000001),
#   (11, 0.010000001),
#   (12, 0.010000001),
#   (13, 0.010000001),
#   (14, 0.010000001),
#   (15, 0.010000001),
#   (16, 0.010000001),
#   (17, 0.010000001),
#   (18, 0.010000001),
#   (19, 0.010000001),
#   (20, 0.010000001),
#   (21, 0.010000001),
#   (22, 0.010000001),
#   (23, 0.010000001),
#   (24, 0.010000001)],
#  [(0, [9])],
#  [(0, [(9, 2.9999995)])])

# %% [markdown]
# For looking at the details of a specific topic, and its word distribution, you can query the lda_model directly. The `topn` variable shows how many items to display

# %%
lda_model.show_topic(21, topn=30)
# Out:
# [('god', 0.20524834),
#  ('people', 0.08997392),
#  ('power', 0.0812579),
#  ('faith', 0.057230312),
#  ('christian', 0.05547319),
#  ('life', 0.05419738),
#  ('word', 0.049899396),
#  ('world', 0.045320693),
#  ('way', 0.031713385),
#  ('human', 0.030553361),
#  ('reality', 0.025296446),
#  ('experience', 0.023166098),
#  ('doe', 0.021962931),
#  ('tulud', 0.019804804),
#  ('need', 0.016158376),
#  ('especially', 0.013886022),
#  ('like', 0.01281783),
#  ('sense', 0.012462943),
#  ('particularly', 0.011948879),
#  ('fact', 0.011376779),
#  ('just', 0.01132918),
#  ('make', 0.011165283),
#  ('time', 0.0108135445),
#  ('g', 0.010585245),
#  ('relation', 0.009754408),
#  ('good', 0.00956607),
#  ('example', 0.009151671),
#  ('culture', 0.008596516),
#  ('context', 0.008572249),
#  ('challenge', 0.007773363)]

# %%
sent_topics_df = format_topics_sent(lda_model, corpus, text_list)

# %%
sent_topics_df
# Out:
#       Dominant_topic  Perc_Contrib  \
# 0                9.0        0.7600
# 1                9.0        0.6080
# 2                9.0        0.6800
# 3               21.0        0.5200
# 4                9.0        0.6040
# 5                9.0        0.8629
# 6                9.0        0.8080
# 7               14.0        0.5200
# 8                0.0        0.0400
# 9                9.0        0.6800
# 10               9.0        0.8400
# 11               9.0        0.7600
# 12               0.0        0.0400
# 13              17.0        0.5200
# 14               9.0        0.5200
# 15               5.0        0.5200
# 16              13.0        0.4080
# 17              14.0        0.4080
# 18               0.0        0.0400
# 19               7.0        0.3448
# 20               8.0        0.2205
# 21              20.0        0.4337
# 22              18.0        0.6215
# 23              20.0        0.4992
# 24              24.0        0.2211
# 25              20.0        0.4348
# 26              20.0        0.4400
# 27              20.0        0.2912
# 28              20.0        0.5509
# 29               3.0        0.2221
# ...              ...           ...
# 1089             7.0        0.5100
# 1090             5.0        0.4263
# 1091             0.0        0.0400
# 1092             9.0        0.2080
# 1093            13.0        0.6800
# 1094             9.0        0.3467
# 1095             9.0        0.3467
# 1096             4.0        0.5095
# 1097            11.0        0.5200
# 1098             7.0        0.5200
# 1099             9.0        0.3467
# 1100             9.0        0.5771
# 1101             0.0        0.0400
# 1102             4.0        0.5200
# 1103             0.0        0.0400
# 1104             9.0        0.3467
# 1105            12.0        0.5200
# 1106            21.0        0.5100
# 1107             0.0        0.0400
# 1108             4.0        0.3467
# 1109             7.0        0.5100
# 1110            23.0        0.6080
# 1111            17.0        0.3276
# 1112            23.0        0.5200
# 1113            23.0        0.3738
# 1114             5.0        0.2232
# 1115            20.0        0.3811
# 1116            20.0        0.5257
# 1117             2.0        0.4688
# 1118            24.0        0.2966
#
#                                          Topic_Keywords  \
# 0     œ, dorottya, martha, human, order, case, g, st...
# 1     œ, dorottya, martha, human, order, case, g, st...
# 2     œ, dorottya, martha, human, order, case, g, st...
# 3     god, people, power, faith, christian, life, wo...
# 4     œ, dorottya, martha, human, order, case, g, st...
# 5     œ, dorottya, martha, human, order, case, g, st...
# 6     œ, dorottya, martha, human, order, case, g, st...
# 7     right, human, word, reality, state, world, tim...
# 8     black, experience, life, mean, like, make, poi...
# 9     œ, dorottya, martha, human, order, case, g, st...
# 10    œ, dorottya, martha, human, order, case, g, st...
# 11    œ, dorottya, martha, human, order, case, g, st...
# 12    black, experience, life, mean, like, make, poi...
# 13    research, form, study, mean, need, way, order,...
[../pdfs/Cruz - 2010 - Chapter Six. Expanding ...
# 155   [../pdfs/Frederiks and Nagy - 2016 - Religion,...
# 572                  [../pdfs/Soares et al 2017.pdf, 4]
# 74    [../pdfs/Frederiks and Nagy - 2016 - Religion,...
# 212   [../pdfs/Frederiks and Nagy - 2016 - Religion,...
# 968   [../pdfs/Cruz - 2010 - Chapter Five. A Differe...
# 233   [../pdfs/Frederiks and Nagy - 2016 - Religion,...
# 573                  [../pdfs/Soares et al 2017.pdf, 5]
# 214   [../pdfs/Frederiks and Nagy - 2016 - Religion,...
# 620   [../pdfs/Cruz - 2010 - Chapter Four. Exploring...
# 511   [../pdfs/Cruz - 2010 - Chapter Two. Frontiers ...
# 806   [../pdfs/Cruz - 2010 - Chapter Three. Expandin...
# 578   [../pdfs/Cruz - 2010 - Chapter Four. Exploring...
# 292         [../pdfs/Cruz - 2010 - Introduction.pdf, 0]
# 621   [../pdfs/Cruz - 2010 - Chapter Four. Exploring...
# 568                  [../pdfs/Soares et al 2017.pdf, 0]
# 970   [../pdfs/Cruz - 2010 - Chapter Five. A Differe...
# 35    [../pdfs/Cruz - 2010 - Chapter Six. Expanding ...
# 448                          [../pdfs/cruz2010.pdf, 16]
# 340   [../pdfs/Cruz - 2010 - Chapter One. Geographie...
# 498   [../pdfs/Cruz - 2010 - Chapter Two. Frontiers ...
#
# [109 rows x 4 columns]

# %% [markdown]
# To explore each topic was helpful, but one of the things we wanted to see was a shorter dataframe that had the topics and which document best exemplified those documents. The next cell groups the dataframe by the dominant topic, and the next cell creates a new dataframe so that just the best exemplified topics are portrayed.

# %%
grpd_df = sent_topics_df.groupby('Dominant_topic')

# %%
# This code creates a pandas DataFrame that shows which document is exemplified by which topic
new_df = pd.DataFrame()

for i, grp in grpd_df:
    new_df = pd.concat([new_df, grp.sort_values(['Perc_Contrib'], ascending=[0]).head(1)], axis=0)

new_df.reset_index(drop=True, inplace=True)
new_df.columns = ['Topic_Num', 'Topic_Perc_Contrib', 'Keywords', 'Text']
new_df
# Out:
#     Topic_Num  Topic_Perc_Contrib  \
# 0         0.0              0.5200
# 1         1.0              0.5854
# 2         2.0              0.4688
# 3         3.0              0.5200
# 4         4.0              0.5200
# 5         5.0              0.7828
# 6         6.0              0.6744
# 7         7.0              0.6938
# 8         8.0              0.4646
# 9         9.0              0.9751
# 10       10.0              0.6800
# 11       11.0              0.5710
# 12       12.0              0.6930
# 13       13.0              0.7600
# 14       14.0              0.5200
# 15       15.0              0.5200
# 16       16.0              0.5200
# 17       17.0              0.5653
# 18       18.0              0.6215
# 19       19.0              0.6800
# 20       20.0              0.6381
# 21       21.0              0.7600
# 22       23.0              0.7664
# 23       24.0              0.5721
#
#                                              Keywords  \
# 0   black, experience, life, mean, like, make, poi...
# 1   identity, challenge, term, experience, context...
# 2   worker, domestic, migrant, filipina, condition...
# 3   migrant, country, home, community, family, exp...
# 4   migration, context, study, challenge, communit...
# 5   social, political, economic, immigrant, societ...
# 6   church, christian, american, immigrant, commun...
# 7   theology, experience, theological, tulud, cont...
# 8   group, community, religious, social, role, tim...
# 9   œ, dorottya, martha, human, order, case, g, st...
# 10  say, way, make, problem, time, life, mean, peo...
# 11  religion, religious, culture, cultural, christ...
# 12  work, place, family, home, like, case, make, m...
# 13  new, press, ed, york, power, study, global, pe...
# 14  right, human, word, reality, state, world, tim...
# 15  service, relationship, sense, work, good, espe...
# 16  theological, book, human, faith, case, g, life...
# 17  research, form, study, mean, need, way, order,...
# 18  woman, feminist, oppression, tulud, particular...
# 19  mission, world, international, dorottya, marth...
# 20  struggle, woman, life, oppression, feminist, e...
# 21  god, people, power, faith, christian, life, wo...
# 22  hong, kong, tulud, filipina, filipino, g, huma...
# 23  filipino, philippine, hk, migrant, tulud, just...
#
#                                                  Text
# 0                     [../pdfs/Rowlands 2018.pdf, 16]
# 1   [../pdfs/Frederiks and Nagy - 2016 - Religion,...
# 2   [../pdfs/Cruz - 2010 - Preliminary Material.pd...
# 3                       [../pdfs/Snyder 2018.pdf, 16]
# 4                        [../pdfs/Snyder 2018.pdf, 5]
# 5                       [../pdfs/Jimenez 2019.pdf, 7]
# 6                       [../pdfs/Nnamani 2015.pdf, 5]
# 7                          [../pdfs/cruz2010.pdf, 34]
# 8   [../pdfs/Frederiks and Nagy - 2016 - Religion,...
# 9   [../pdfs/Frederiks and Nagy - 2016 - Religion,...
# 10                       [../pdfs/Strine 2018.pdf, 8]
# 11                     [../pdfs/Nnamani 2015.pdf, 14]
# 12  [../pdfs/Cruz - 2010 - Chapter Two. Frontiers ...
# 13                      [../pdfs/Snyder 2018.pdf, 17]
# 14                     [../pdfs/Davidson 2018.pdf, 7]
# 15                     [../pdfs/Rowlands 2018.pdf, 0]
# 16                     [../pdfs/Thompson 2017.pdf, 0]
# 17  [../pdfs/Frederiks and Nagy - 2016 - Religion,...
# 18  [../pdfs/Cruz - 2010 - Chapter Six. Expanding ...
# 19  [../pdfs/Frederiks and Nagy - 2016 - Religion,...
# 20                         [../pdfs/cruz2010.pdf, 27]
# 21                     [../pdfs/Thompson 2017.pdf, 3]
# 22  [../pdfs/Cruz - 2010 - An intercultural theolo...
# 23  [../pdfs/Cruz - 2010 - Chapter One. Geographie...

# %% [markdown]
# # Details of the Topic Model
#
# One of the problems with topic modeling is that because it is an unsupervised clustering method, sometimes the computer sees connections that are not obvious, or at the vary least, are not _semantic_ clusters. Topic model is a blunt tool, but we picked six of these topics that we thought might be helpful in discovering books over the past 100 years that might build on the topic we had chosen.
#
# These topics are:
#
# * _topic number_: 0
#    * _heading_: *Black Experience*
#    * _key terms_: 'black, experience, life, mean, like, make, point, american, challenge, relation'
# * _topic number_: 1
#    * _heading_: *Context of Migrant Experience*
#    * _key terms_: 'identity, challenge, term, experience, context, question, migrant, people, state, dorottya'
# *  _topic number_: 3
#    * _heading_: *Communal Experience*
#    * _key terms_: 'migrant, country, home, community, family, experience, life, economic, new, reality'
# * _topic number_: 5
#    * _heading_: *Social, Political, Economic Migrations*
#    * _key terms_: 'social, political, economic, immigrant, society, cultural, perspective, issue, people, life'
# * _topic number_: 6
#    * _heading_: *Immigration and American Christianity*
#    * _key terms_: 'church, christian, american, immigrant, community, role, dorottya, martha, state, faith'
# * _topic number_: 11
#    * _heading_: *Religion and Culture*
#    * _key terms_: 'religion, religious, culture, cultural, christian, identity, faith, experience, example, time'
#
#
# These topics were analysed in the context of the pdfs that generated them. These where the topics that we thought were both coherent, and might provide interesting analysis when looked at the political theology corpus generated from HathiTrust.
#
# These are the only six topics we looked for in the HathiTrust corpus that we had identified.
